# %%
dbutils.library.restartPython()

# %% [markdown]
# # 00 — Download Landing Zone
# Baixa os arquivos parquet de yellow táxi (Jan–Mai/2023) da NYC TLC direto
# para a landing zone (Unity Catalog Volume), sem transformação.

# %% [markdown]
# ### Imports

# %%
from src.bronze import download_taxi_data
from src.config import LAKE, INGESTION

print("Landing path:", LAKE.landing_path)
print("Meses configurados:", INGESTION.months)

# %% [markdown]
# ### Downloads

# %%
downloaded_files = download_taxi_data.run()
downloaded_files

# %% [markdown]
# ### Confirmação visual dos arquivos no volume

# %%
# %sh ls -lh /Volumes/workspace/default/ifood_case/landing/yellow_taxi
