# %%
dbutils.library.restartPython()

# %% [markdown]
# # 03 — Silver to Gold
# Agrega os dados da Silver em duas tabelas de consumo, respondendo
# diretamente as perguntas de negócio do case:
# 1. Média de `total_amount` por mês (toda a frota)
# 2. Média de `passenger_count` por hora do dia, em maio/2023

# %%
from src.gold import silver_to_gold

silver_to_gold.run()

# %%
# %sql
-- Qual a média de valor total (total\_amount) recebido em um mês considerando todos os yellow táxis da frota?
SELECT * FROM workspace.gold.avg_total_amount_by_month
ORDER BY trip_year, trip_month

# %%
# %sql
-- Qual a média de passageiros (passenger\_count) por cada hora do dia que pegaram táxi no mês de maio considerando todos os táxis da frota?
SELECT * FROM workspace.gold.avg_passenger_count_by_hour_may
ORDER BY pickup_hour

# %%
# %sql
-- Checagem final
SHOW TABLES IN workspace.gold
