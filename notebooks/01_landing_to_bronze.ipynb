# %% [markdown]
# # 01 — Landing to Bronze
# Lê os parquets da landing zone, adiciona metadados técnicos
# (`_ingested_at`, `_source_file`, `_ref_year`, `_ref_month`) e grava como
# tabela Delta gerenciada em `workspace.bronze.yellow_taxi_trips`.

# %%
from src.ingestion import landing_to_bronze

landing_to_bronze.run()

# %%
# %sql
-- Inspeciona o resultado
SELECT * FROM workspace.bronze.yellow_taxi_trips LIMIT 10

# %%
# %sql
-- Confere a volumetria e o schema
SELECT _ref_year, _ref_month, COUNT(*) AS registros
FROM workspace.bronze.yellow_taxi_trips
GROUP BY _ref_year, _ref_month
ORDER BY _ref_year, _ref_month

# %%
# %sql
DESCRIBE TABLE workspace.bronze.yellow_taxi_trips
