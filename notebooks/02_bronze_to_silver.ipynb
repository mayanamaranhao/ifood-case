# %% [markdown]
# # 02 — Bronze to Silver
# Aplica tipagem, renomeia para snake_case, filtra registros inválidos
# (regras de qualidade) e deduplica. Grava como tabela Delta gerenciada em
# `workspace.silver.yellow_taxi_trips`.

# %%
from src.transformation import bronze_to_silver

bronze_to_silver.run()

# %%
# %sql
SELECT * FROM workspace.silver.yellow_taxi_trips LIMIT 10

# %%
# %sql
-- Volumetria por mês na Silver
SELECT trip_year, trip_month, COUNT(*) AS registros
FROM workspace.silver.yellow_taxi_trips
GROUP BY trip_year, trip_month
ORDER BY trip_year, trip_month

# %%
# %sql
-- Comparativo Bronze vs Silver (evidencia quantos registros a limpeza descartou)
SELECT
    (SELECT COUNT(*) FROM workspace.bronze.yellow_taxi_trips) AS registros_bronze,
    (SELECT COUNT(*) FROM workspace.silver.yellow_taxi_trips) AS registros_silver

# %%
# %sql
DESCRIBE TABLE workspace.silver.yellow_taxi_trips
